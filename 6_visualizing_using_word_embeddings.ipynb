# %% [markdown]
# <a href="https://colab.research.google.com/github/mrishikreddy/nlp/blob/main/6_visualizing_using_word_embeddings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
import gensim.downloader as api
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
word_vectors = api.load("glove-wiki-gigaword-100")
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %%
words = ['king','queen','man','woman','paris','france','london','england']
word_vecs = [word_vectors[word] for word in words]
pcs = PCA(n_components=2)
result = pcs.fit_transform(word_vecs)

# %%
plt.figure(figsize=(8,6))
plt.scatter(result[:,0], result[:,1],c='red')

# %%
for i, word in enumerate(words):
  plt.annotate(word, xy=(result[i,0],result[i,1]))
plt.title("Word Embeddings Visualized using PCA")
plt.show()
